# %%
import pandas as pd

# %%
gtd = pd.read_excel("../data/raw/globalterrorismdb_0522dist.xlsx")

# %%
pakistan = gtd[gtd["country_txt"] == "Pakistan"].copy()

# %%
pakistan.shape
# Out:
# (15504, 135)

# %%
pakistan.head()
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 585   197011010001   1970      11     1        NaN         0        NaT
# 2216  197402020001   1974       2     2        NaN         1 1974-02-03
# 2704  197412090001   1974      12     9        NaN         0        NaT
# 2743  197500000001   1975       0     0        NaN         0        NaT
# 2794  197502080001   1975       2     8        NaN         0        NaT
#
#       country country_txt  region  ... addnotes scite1 scite2  scite3  \
# 585       153    Pakistan       6  ...      NaN    NaN    NaN     NaN
# 2216      153    Pakistan       6  ...      NaN    NaN    NaN     NaN
# 2704      153    Pakistan       6  ...      NaN    NaN    NaN     NaN
# 2743      153    Pakistan       6  ...      NaN    NaN    NaN     NaN
# 2794      153    Pakistan       6  ...      NaN    NaN    NaN     NaN
#
#       dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
pakistan.to_excel('pakistan.xlsx', index=False)

# %%
pakistan.to_excel('../data/processed/pakistan.xlsx', index=False)
